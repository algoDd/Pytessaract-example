# %%
import os
import pytesseract
import cv2
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img,cmap="Greys")

# %%
img = Image.open("EpoAutomationContent.jpeg")
text = pytesseract.image_to_string(img, lang = 'eng')
print(text)
# Out:
# I) a bunk»: kw mm”: ”“13“ Muuml hey: Wayne-3‘
#
# 9119'» my.“ “Wmmgu , menu-5:. naval- .
#
# Ina-um»! Sua‘ Hm muundw wwun ways!
# «yuan, u.) qua, trout, “ﬁlly.
# 3". Lamp“ “wwm may: now; wuakk
# mmwmgl Newtoh’miy
#
# M wlmc ﬂu Mikael ‘7:qu WW
#
# 5 u urn-cum , .
# W" e: 'ﬁ’ﬁ’f‘ ‘ (“’“5’
# . '4“ - -...: V!‘

# %%
f=open("text.txt","w")
f.write(text)
f.close()
